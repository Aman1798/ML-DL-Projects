# %% [markdown]
# **IRIS FLOWER DATASET ANALYSIS**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# How many data-points and features(rows & column)
print(iris.shape)
# Out:
# (150, 5)

# %%
# Column name in dataset
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#Data Insights
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_duplicate = iris.duplicated()
iris[iris_duplicate]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 34            4.9          3.1           1.5          0.1     setosa
# 37            4.9          3.1           1.5          0.1     setosa
# 142           5.8          2.7           5.1          1.9  virginica

# %%
# How many data points for each class are present

iris["species"].value_counts()
# balanced vs Imbalanced dataset
# Iris is balanced dataset as every class has equal data points
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# we shouldn’t delete the duplicate entries as it might imbalance the data sets and hence will prove to be less useful for valuable insights

# %%
#Species Count

plt.title("Species Count")
sns.countplot(x="species", data=iris)
# Out:
# <Axes: title={'center': 'Species Count'}, xlabel='species', ylabel='count'>

# %% [markdown]
# Scatter plot without colour coding

# %%
# Plot scatter plot
iris.plot(kind="scatter", x="sepal_length", y="sepal_width")
iris.plot(kind="scatter", x="petal_length", y="petal_width")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Scatter plot with color coding

# %%
# 2-d scatter plot with color-coding
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", height=4).map(
    plt.scatter, "sepal_length", "sepal_width"
).add_legend()
sns.FacetGrid(iris, hue="species", height=4).map(
    plt.scatter, "petal_length", "petal_width"
).add_legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 3-D scatter plot
plt.close()
sns.set_style("whitegrid")
sns.pairplot(iris, hue="species", height=3, diag_kind="kde")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Checking mean & median values

iris_MeanMedian = iris.groupby("species").agg(['mean','median'])
iris_MeanMedian
# Out:
#            sepal_length        sepal_width        petal_length         \
#                    mean median        mean median         mean median
# species
# setosa            5.006    5.0       3.418    3.4        1.464   1.50
# versicolor        5.936    5.9       2.770    2.8        4.260   4.35
# virginica         6.588    6.5       2.974    3.0        5.552   5.55
#
#            petal_width
#                   mean median
# species
# setosa           0.244    0.2
# versicolor       1.326    1.3
# virginica        2.026    2.0

# %%
plt.close()
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", height=5).map(sns.histplot, "petal_length").add_legend()
sns.FacetGrid(iris, hue="species", height=5).map(sns.histplot, "sepal_length").add_legend()
sns.FacetGrid(iris, hue="species", height=5).map(sns.histplot, "petal_width").add_legend()
sns.FacetGrid(iris, hue="species", height=5).map(sns.histplot, "sepal_length").add_legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Classification
sns.FacetGrid(iris, hue="species", height=5).map(sns.distplot, "petal_length").add_legend()
sns.FacetGrid(iris, hue="species", height=5).map(sns.distplot, "sepal_length").add_legend()
sns.FacetGrid(iris, hue="species", height=5).map(sns.distplot, "petal_width").add_legend()
sns.FacetGrid(iris, hue="species", height=5).map(sns.distplot, "sepal_length").add_legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# We will choose Classification feature as Petal Length to distinguish among the species

# %%
iris_setosa = iris["species"]=="setosa"
new_iris_setosa = iris[iris_setosa]

iris_versicolor = iris["species"]=="versicolor"
new_iris_versicolor = iris[iris_versicolor]

iris_virginica = iris["species"]=="virginica"
new_iris_virginica = iris[iris_virginica]

# %%
#CDF & PDF of petal_length wrt setosa
counts, bin_edges = np.histogram(new_iris_setosa["petal_length"], bins=10, density=True)


pdf = counts / (sum(counts)) # compute PDF
print(f'pdf = {pdf}')
print(f'bin_edges = {bin_edges}')


cdf = np.cumsum(pdf) # compute CDF

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)
plt.legend()
plt.gca().legend(('pdf', 'cdf'))
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# pdf = [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# bin_edges = [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
#CDF & PDF of petal_length wrt versicolor
counts, bin_edges = np.histogram(new_iris_versicolor["petal_length"], bins=10, density=True)


pdf = counts / (sum(counts)) # compute PDF
print(f'pdf = {pdf}')
print(f'bin_edges = {bin_edges}')


cdf = np.cumsum(pdf) # compute CDF

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)
plt.legend()
plt.gca().legend(('pdf', 'cdf'))
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# pdf = [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# bin_edges = [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %%
#CDF & PDF of petal_length wrt verginica
counts, bin_edges = np.histogram(new_iris_virginica["petal_length"], bins=10, density=True)


pdf = counts / (sum(counts)) # compute PDF
print(f'pdf = {pdf}')
print(f'bin_edges = {bin_edges}')


cdf = np.cumsum(pdf) # compute CDF

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)
plt.legend()
plt.gca().legend(('pdf', 'cdf'))
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# pdf = [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# bin_edges = [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]

# %%
#Box Plot
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.set_style("whitegrid")
sns.boxplot(x="species", y="petal_length", data=iris, orient='v',ax=axes[0, 1])
sns.boxplot(x="species", y="petal_width", data=iris, orient='v',ax=axes[0, 0])
sns.boxplot(x="species", y="sepal_length", data=iris,orient='v', ax=axes[1, 0])
sns.boxplot(x="species", y="sepal_width", data=iris,orient='v', ax=axes[1, 1])
plt.show()

# %% [markdown]
# -Setosa exhibits smaller features and a narrower distribution.
# -Versicolor displays a moderate level of distribution and features of average size.
# -Virginica showcases a high degree of distribution with a substantial number of values and large features.

# %% [markdown]
# ***Creating a model to classify different species of IRIS Flower***
